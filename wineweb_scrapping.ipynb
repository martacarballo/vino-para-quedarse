# %%
import requests
from bs4 import BeautifulSoup
import json

url = "https://www.vivino.com/es/explore?e=eJzLLbI1VMvNzLM1UMtNrLA1NTBQS660TS1WS7Z1DQ1SKwDKpqfZliUWZaaWJOao5Rel2KakFier5SdV2hYUZSanqpUXR8faGloYqBUBaRMDUwBHtxqD"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/123.0 Safari/537.36",
}
response = requests.get(url, headers=headers)
response
# Out:
# <Response [200]>

# %%
soup = BeautifulSoup(response.content, "html.parser")
# Leemos el contenido de la web
response.content
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="es">
# <head>
# <meta charset="utf-8"/>
# <meta content="#a61a30" name="theme-color"/>
# <title>    Ribera del Duero Tinto (España), above €0, rated 1 or more
# </title>
# <meta content="Vivino’s wine explorer presents Ribera del Duero Tinto (España), rated 1 or more, with a price above €0" name="description"/>
# <script defer="" src="https://b9cbbfa2974c.edge.sdk.awswaf.com/b9cbbfa2974c/94b2e38dda14/challenge.js" type="text/javascript"></script>
# <script charset="UTF-8" data-domain-script="0195a559-6f43-7c13-8884-cee88b4a00a5" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript">
# </script>
# <script type="text/javascript">
#     function isBannerVisible() {
#       const banner = document.getElementById('onetrust-banner-sdk');
#       if (!banner) return false;
#       const style = getComputedStyle(banner);
#       return style.display !== 'none' && style.visibility !== 'hidden' && style.opacity !== '0';
#     }
#
# ...

# %%
# Mostramos las cabeceras de la HTTP
response.headers
# Out:
# {'Content-Type': 'text/html; charset=utf-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Date': 'Sat, 08 Nov 2025 14:34:28 GMT', 'X-Content-Type-Options': 'nosniff', 'Set-Cookie': 'first_time_visit=MpjObwRsVb9mVYjo7C9E8I0DwI0STspjMBssuYDeZCvE5jn6A3CnLGfaq0WcbnrcnSij7RoeiMGAWwdD13s6kuRiRpa%2Bl09PvFyIT55abOWTb0TZf8r1nJfMqTgKmTpKHIg%3D--%2Fs55I3TbhoDIWxPS--1JINqeyf9eecPby58LX%2BYg%3D%3D; path=/; expires=Thu, 08 Nov 2035 14:34:27 GMT; SameSite=Lax; secure; HttpOnly, anonymous_tracking_id=%2FnIRthCxumu3LgafwtIq9LetwmL7J6ABzke2EanP3%2FWMgyk2gGJrhX8Xnh%2BkpTxsvfT52qaXp%2FcwTjlCMlCmB7xKb5WGPhDSNg97w5xs6Y%2Bw3C1%2FTCKxt4MBC2cNXX6FXY0OSzTDR6EW9wjWgyeNUArF14hvml8ANDNjWGo9vrMSbKi7QsPwkJNxaP1QS7VZg1wr--oVBHo0J%2BY7jcWsMa--817yspMJBlFvdR%2BhgHGCVA%3D%3D; path=/; expires=Thu, 08 Nov 2035 14:34:27 GMT; SameSite=Lax; secure; HttpOnly, mixpanel_tracking_id=c24c4366-ef86-413e-8bd0-9d2b9cec7e49; path=/; expires=Mon, 08 Nov 2027 14:34:28 GMT; SameSite=Lax; secure; HttpOnly, client_cache_
# ...

# %%
soup.find("title")
# Out:
# <title>    Ribera del Duero Tinto (España), above €0, rated 1 or more
# </title>

# %%
# Seleccionamos los p elementos
soup.select("p")
# Out:
# [<p class="MuiTypography-root MuiTypography-body1 querySummary-module__querySummary--N60Ix vivino-mui-ssvfeg-MuiTypography-root-bodyMedium">Mostrando<!-- --> <!-- -->1-24 de <!-- -->2186<!-- --> <!-- -->VINOS</p>]

# %%
len(soup.select("div div div div div div div div span"))
# Out:
# 118

# %%
soup.select("div div div div div div div div")
# Out:
# [<div class="navigationItem-module__labelContainer--DT-x2"><form class="searchBar-module__searchForm--BSOFj"><input aria-label="Buscar cualquier vino" autocomplete="off" class="searchBar-module__searchInput--bDAqE" maxlength="200" name="q" placeholder="Buscar cualquier vino" style="background-image:url(https://web-common.testing.vivino.com/assets/search.svg)" type="text" value=""/></form></div>,
#  <div class="simpleLabel-module__selectedKey--3ngzL"><span class="simpleLabel-module__label--3P-g3">Enviar a</span>España</div>,
#  <div class="simpleLabel-module__selectedKey--3ngzL"><span class="simpleLabel-module__label--3P-g3">Idioma</span>Español</div>,
# ...

# %%
# 1) Buscar el <script> que contiene el JSON
script_tag = soup.find("script", id="js-react-on-rails-context", type="application/json")

if script_tag is None:
    raise ValueError("No he encontrado el script con id='js-react-on-rails-context'")

# 2) Cargar el JSON
data = json.loads(script_tag.string)

# 3) Explorar la estructura (primero mira qué claves hay)
print(data.keys())


# Por ejemplo:
for k, v in data.items():
    print(k, type(v))

# Esto es SOLO un ejemplo de cómo podría ser,
# tú tienes que usar las claves reales que veas al imprimir data
explore = data["props"]["pageProps"]["exploreV2"]

items = explore["matches"]  # o "wines", "items", etc., según lo que veas

rows = []
for item in items:
    # Aquí de nuevo, claves de ejemplo; ajusta a lo que tenga tu JSON
    wine = item["vintage"]["wine"]
    stats = item["vintage"]["statistics"]

    row = {
        "name": wine.get("name"),
        "region": wine.get("region", {}).get("name"),
        "country": wine.get("region", {}).get("country", {}).get("name"),
        "grapes": ", ".join(g["name"] for g in wine.get("grapes", [])),
        "rating": stats.get("ratings_average"),
        "ratings_count": stats.get("ratings_count"),
        # añade lo que te interese
    }
    rows.append(row)

df = pd.DataFrame(rows)
df.head()
# Out:
# dict_keys(['railsEnv', 'inMailer', 'i18nLocale', 'i18nDefaultLocale', 'rorVersion', 'rorPro', 'href', 'location', 'scheme', 'host', 'port', 'pathname', 'search', 'httpAcceptLanguage', 'serverSide'])
# railsEnv <class 'str'>
# inMailer <class 'bool'>
# i18nLocale <class 'str'>
# i18nDefaultLocale <class 'str'>
# rorVersion <class 'str'>
# rorPro <class 'bool'>
# href <class 'str'>
# location <class 'str'>
# scheme <class 'str'>
# host <class 'str'>
# port <class 'NoneType'>
# pathname <class 'str'>
# search <class 'str'>
# httpAcceptLanguage <class 'NoneType'>
# serverSide <class 'bool'>
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 20
#      16     print(k, type(v))
#      18 # Esto es SOLO un ejemplo de cómo podría ser,
#      19 # tú tienes que usar las claves reales que veas al imprimir data
# ---> 20 explore = data["props"]["pageProps"]["exploreV2"]
# ...
